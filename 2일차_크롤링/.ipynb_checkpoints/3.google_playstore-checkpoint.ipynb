# %% [markdown]
# ## 구글 플레이 스토어 댓글 수집기
# - 내가 검색한 앱의 댓글을 수집합니다. (최소 스크롤 3번을 내립니다.)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# %%
path = "/Users/inseop/Desktop/python/python-miyoung/2일차_크롤링/chromedriver"

browser = webdriver.Chrome(path) # "./chromedriver.exe"
# Out:
# /var/folders/sb/yyvqcbn90d979xflbm03f1480000gn/T/ipykernel_73140/2207422390.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(path) # "./chromedriver.exe"

# %%
search_word = input("검색하시고자 하는 앱 이름을 입력하세요.")

url = "https://play.google.com/store/search?q={}&c=apps"

final_url = url.format(search_word)
print(final_url)
browser.get(final_url)

time.sleep(3)
browser.implicitly_wait(5)
app_url = browser.find_element(By.CLASS_NAME, 'Si6A0c').get_attribute('href')
print(app_url)

browser.get(app_url)
# Out:
# 검색하시고자 하는 앱 이름을 입력하세요.쿠팡
# https://play.google.com/store/search?q=쿠팡&c=apps
# https://play.google.com/store/apps/details?id=com.coupang.mobile

# %%
# browser.find_element(By.CLASS_NAME, 'VfPpkd-Bz112c-Jh9lGc').click()

browser.find_element(By.XPATH, '//*[@id="yDmH0d"]/c-wiz[2]/div/div/div[1]/div[2]/div/div[1]/c-wiz[4]/section/header/div/div[2]/button').click()

# %%
pip install pyautogui
# Out:
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.53.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pymsgbox
#   Using cached PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting PyTweening>=1.0.1
#   Downloading pytweening-1.0.4.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.28.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pygetwindow>=0.0.5
#   Using cached PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mouseinfo
#   Using cached MouseInfo-0.1.3.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyobjc-core
#   Downloading pyobjc_core-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (578 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.8/578.8 kB 9.8 MB/s eta 0:00:00m eta 0:00:01
# Collecting pyobjc
#   Downloading pyobjc-8.5.1-py3-none-any.whl (3.8 kB)
# Collecting pyrect
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyperclip
#   Using cached pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting rubicon-objc
#   Downloading rubicon_objc-0.4.2-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 1.9 MB/s eta 0:00:00
# Collecting pyobjc-framework-OpenDirectory==8.5.1
#   Downloading pyobjc_framework_OpenDirectory-8.5.1-py2.py3-none-any.whl (11 kB)
# Collecting pyobjc-framework-CoreAudioKit==8.5.1
#   Downloading pyobjc_framework_CoreAudioKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (5.5 kB)
# Collecting pyobjc-framework-GameplayKit==8.5.1
#   Downloading pyobjc_framework_GameplayKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (8.4 kB)
# Collecting pyobjc-framework-DiskArbitration==8.5.1
#   Downloading pyobjc_framework_DiskArbitration-8.5.1-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-SoundAnalysis==8.5.1
#   Downloading pyobjc_framework_SoundAnalysis-8.5.1-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-Speech==8.5.1
#   Downloading pyobjc_framework_Speech-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (6.4 kB)
# Collecting pyobjc-framework-DeviceCheck==8.5.1
#   Downloading pyobjc_framework_DeviceCheck-8.5.1-py2.py3-none-any.whl (3.2 kB)
# Collecting pyobjc-framework-MLCompute==8.5.1
#   Downloading pyobjc_framework_MLCompute-8.5.1-py2.py3-none-any.whl (6.1 kB)
# Collecting pyobjc-framework-Vision==8.5.1
#   Downloading pyobjc_framework_Vision-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (9.9 kB)
# Collecting pyobjc-framework-Accounts==8.5.1
#   Downloading pyobjc_framework_Accounts-8.5.1-py2.py3-none-any.whl (4.6 kB)
# Collecting pyobjc-framework-DiscRecording==8.5.1
#   Downloading pyobjc_framework_DiscRecording-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-LocalAuthentication==8.5.1
#   Downloading pyobjc_framework_LocalAuthentication-8.5.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pyobjc-framework-SafariServices==8.5.1
#   Downloading pyobjc_framework_SafariServices-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (5.8 kB)
# Collecting pyobjc-framework-AutomaticAssessmentConfiguration==8.5.1
#   Downloading pyobjc_framework_AutomaticAssessmentConfiguration-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (6.4 kB)
# Collecting pyobjc-framework-UniformTypeIdentifiers==8.5.1
#   Downloading pyobjc_framework_UniformTypeIdentifiers-8.5.1-py2.py3-none-any.whl (4.0 kB)
# Collecting pyobjc-framework-DictionaryServices==8.5.1
#   Downloading pyobjc_framework_DictionaryServices-8.5.1-py2.py3-none-any.whl (3.4 kB)
# Collecting pyobjc-framework-DataDetection==8.5.1
#   Downloading pyobjc_framework_DataDetection-8.5.1-py2.py3-none-any.whl (3.0 kB)
# Collecting pyobjc-framework-CoreHaptics==8.5.1
#   Downloading pyobjc_framework_CoreHaptics-8.5.1-py2.py3-none-any.whl (4.6 kB)
# Collecting pyobjc-framework-CoreMediaIO==8.5.1
#   Downloading pyobjc_framework_CoreMediaIO-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (13 kB)
# Collecting pyobjc-framework-AuthenticationServices==8.5.1
#   Downloading pyobjc_framework_AuthenticationServices-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (9.1 kB)
# Collecting pyobjc-framework-SpriteKit==8.5.1
#   Downloading pyobjc_framework_SpriteKit-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (17 kB)
# Collecting pyobjc-framework-SystemConfiguration==8.5.1
#   Downloading pyobjc_framework_SystemConfiguration-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (16 kB)
# Collecting pyobjc-framework-UserNotifications==8.5.1
#   Downloading pyobjc_framework_UserNotifications-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (7.3 kB)
# Collecting pyobjc-framework-CoreMotion==8.5.1
#   Downloading pyobjc_framework_CoreMotion-8.5.1-py2.py3-none-any.whl (4.7 kB)
# Collecting pyobjc-framework-ReplayKit==8.5.1
#   Downloading pyobjc_framework_ReplayKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (7.2 kB)
# Collecting pyobjc-framework-ScreenTime==8.5.1
#   Downloading pyobjc_framework_ScreenTime-8.5.1-py2.py3-none-any.whl (3.1 kB)
# Collecting pyobjc-framework-CallKit==8.5.1
#   Downloading pyobjc_framework_CallKit-8.5.1-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-CloudKit==8.5.1
#   Downloading pyobjc_framework_CloudKit-8.5.1-py2.py3-none-any.whl (7.8 kB)
# Collecting pyobjc-framework-iTunesLibrary==8.5.1
#   Downloading pyobjc_framework_iTunesLibrary-8.5.1-py2.py3-none-any.whl (4.7 kB)
# Collecting pyobjc-framework-SearchKit==8.5.1
#   Downloading pyobjc_framework_SearchKit-8.5.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-CoreBluetooth==8.5.1
#   Downloading pyobjc_framework_CoreBluetooth-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (9.9 kB)
# Collecting pyobjc-framework-ScriptingBridge==8.5.1
#   Downloading pyobjc_framework_ScriptingBridge-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (6.6 kB)
# Collecting pyobjc-framework-LinkPresentation==8.5.1
#   Downloading pyobjc_framework_LinkPresentation-8.5.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-MediaPlayer==8.5.1
#   Downloading pyobjc_framework_MediaPlayer-8.5.1-py2.py3-none-any.whl (6.0 kB)
# Collecting pyobjc-framework-MetricKit==8.5.1
#   Downloading pyobjc_framework_MetricKit-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (8.6 kB)
# Collecting pyobjc-framework-MediaToolbox==8.5.1
#   Downloading pyobjc_framework_MediaToolbox-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (8.3 kB)
# Collecting pyobjc-framework-PushKit==8.5.1
#   Downloading pyobjc_framework_PushKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (5.9 kB)
# Collecting pyobjc-framework-AudioVideoBridging==8.5.1
#   Downloading pyobjc_framework_AudioVideoBridging-8.5.1-py2.py3-none-any.whl (6.3 kB)
# Collecting pyobjc-framework-ShazamKit==8.5.1
#   Downloading pyobjc_framework_ShazamKit-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (9.0 kB)
# Collecting pyobjc-framework-FileProvider==8.5.1
#   Downloading pyobjc_framework_FileProvider-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (17 kB)
# Collecting pyobjc-framework-ExceptionHandling==8.5.1
#   Downloading pyobjc_framework_ExceptionHandling-8.5.1-py2.py3-none-any.whl (7.4 kB)
# Collecting pyobjc-framework-CoreSpotlight==8.5.1
#   Downloading pyobjc_framework_CoreSpotlight-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (6.9 kB)
# Collecting pyobjc-framework-CoreWLAN==8.5.1
#   Downloading pyobjc_framework_CoreWLAN-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (8.1 kB)
# Collecting pyobjc-framework-AdServices==8.5.1
#   Downloading pyobjc_framework_AdServices-8.5.1-py2.py3-none-any.whl (3.0 kB)
# Collecting pyobjc-framework-CoreText==8.5.1
#   Downloading pyobjc_framework_CoreText-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (30 kB)
# Collecting pyobjc-framework-ServiceManagement==8.5.1
#   Downloading pyobjc_framework_ServiceManagement-8.5.1-py2.py3-none-any.whl (4.5 kB)
# Collecting pyobjc-framework-PencilKit==8.5.1
#   Downloading pyobjc_framework_PencilKit-8.5.1-py2.py3-none-any.whl (3.2 kB)
# Collecting pyobjc-framework-CoreServices==8.5.1
#   Downloading pyobjc_framework_CoreServices-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (27 kB)
# Collecting pyobjc-framework-FileProviderUI==8.5.1
#   Downloading pyobjc_framework_FileProviderUI-8.5.1-py2.py3-none-any.whl (3.2 kB)
# Collecting pyobjc-framework-UserNotificationsUI==8.5.1
#   Downloading pyobjc_framework_UserNotificationsUI-8.5.1-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-ScreenCaptureKit==8.5.1
#   Downloading pyobjc_framework_ScreenCaptureKit-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (9.8 kB)
# Collecting pyobjc-framework-Network==8.5.1
#   Downloading pyobjc_framework_Network-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (14 kB)
# Collecting pyobjc-framework-InstallerPlugins==8.5.1
#   Downloading pyobjc_framework_InstallerPlugins-8.5.1-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-QuickLookThumbnailing==8.5.1
#   Downloading pyobjc_framework_QuickLookThumbnailing-8.5.1-py2.py3-none-any.whl (3.6 kB)
# Collecting pyobjc-framework-MediaLibrary==8.5.1
#   Downloading pyobjc_framework_MediaLibrary-8.5.1-py2.py3-none-any.whl (3.9 kB)
# Collecting pyobjc-framework-NaturalLanguage==8.5.1
#   Downloading pyobjc_framework_NaturalLanguage-8.5.1-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-AppleScriptObjC==8.5.1
#   Downloading pyobjc_framework_AppleScriptObjC-8.5.1-py2.py3-none-any.whl (4.0 kB)
# Collecting pyobjc-framework-MapKit==8.5.1
#   Downloading pyobjc_framework_MapKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (14 kB)
# Collecting pyobjc-framework-CoreAudio==8.5.1
#   Downloading pyobjc_framework_CoreAudio-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (35 kB)
# Collecting pyobjc-framework-WebKit==8.5.1
#   Downloading pyobjc_framework_WebKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (29 kB)
# Collecting pyobjc-framework-Automator==8.5.1
#   Downloading pyobjc_framework_Automator-8.5.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pyobjc-framework-GameController==8.5.1
#   Downloading pyobjc_framework_GameController-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (9.2 kB)
# Collecting pyobjc-framework-CryptoTokenKit==8.5.1
#   Downloading pyobjc_framework_CryptoTokenKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (9.3 kB)
# Collecting pyobjc-framework-Security==8.5.1
#   Downloading pyobjc_framework_Security-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 1.2 MB/s eta 0:00:00
# Collecting pyobjc-framework-PhotosUI==8.5.1
#   Downloading pyobjc_framework_PhotosUI-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (7.8 kB)
# Collecting pyobjc-framework-InstantMessage==8.5.1
#   Downloading pyobjc_framework_InstantMessage-8.5.1-py2.py3-none-any.whl (4.9 kB)
# Collecting pyobjc-framework-CoreLocation==8.5.1
#   Downloading pyobjc_framework_CoreLocation-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (9.3 kB)
# Collecting pyobjc-framework-Intents==8.5.1
#   Downloading pyobjc_framework_Intents-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (21 kB)
# Collecting pyobjc-framework-PassKit==8.5.1
#   Downloading pyobjc_framework_PassKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (9.5 kB)
# Collecting pyobjc-framework-ImageCaptureCore==8.5.1
#   Downloading pyobjc_framework_ImageCaptureCore-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-Social==8.5.1
#   Downloading pyobjc_framework_Social-8.5.1-py2.py3-none-any.whl (4.0 kB)
# Collecting pyobjc-framework-SceneKit==8.5.1
#   Downloading pyobjc_framework_SceneKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (21 kB)
# Collecting pyobjc-framework-SystemExtensions==8.5.1
#   Downloading pyobjc_framework_SystemExtensions-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (6.4 kB)
# Collecting pyobjc-framework-ClassKit==8.5.1
#   Downloading pyobjc_framework_ClassKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (6.3 kB)
# Collecting pyobjc-framework-ExecutionPolicy==8.5.1
#   Downloading pyobjc_framework_ExecutionPolicy-8.5.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-ColorSync==8.5.1
#   Downloading pyobjc_framework_ColorSync-8.5.1-py2.py3-none-any.whl (5.4 kB)
# Collecting pyobjc-framework-CFNetwork==8.5.1
#   Downloading pyobjc_framework_CFNetwork-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-SyncServices==8.5.1
#   Downloading pyobjc_framework_SyncServices-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (10 kB)
# Collecting pyobjc-framework-Virtualization==8.5.1
#   Downloading pyobjc_framework_Virtualization-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (6.8 kB)
# Collecting pyobjc-framework-OSLog==8.5.1
#   Downloading pyobjc_framework_OSLog-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (5.8 kB)
# Collecting pyobjc-framework-VideoSubscriberAccount==8.5.1
#   Downloading pyobjc_framework_VideoSubscriberAccount-8.5.1-py2.py3-none-any.whl (3.8 kB)
# Collecting pyobjc-framework-MediaAccessibility==8.5.1
#   Downloading pyobjc_framework_MediaAccessibility-8.5.1-py2.py3-none-any.whl (3.9 kB)
# Collecting pyobjc-framework-InputMethodKit==8.5.1
#   Downloading pyobjc_framework_InputMethodKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (7.4 kB)
# Collecting pyobjc-framework-FSEvents==8.5.1
#   Downloading pyobjc_framework_FSEvents-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (8.9 kB)
# Collecting pyobjc-framework-MailKit==8.5.1
#   Downloading pyobjc_framework_MailKit-8.5.1-py2.py3-none-any.whl (4.1 kB)
# Collecting pyobjc-framework-KernelManagement==8.5.1
#   Downloading pyobjc_framework_KernelManagement-8.5.1-py2.py3-none-any.whl (3.2 kB)
# Collecting pyobjc-framework-CoreData==8.5.1
#   Downloading pyobjc_framework_CoreData-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (13 kB)
# Collecting pyobjc-framework-Contacts==8.5.1
#   Downloading pyobjc_framework_Contacts-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (9.1 kB)
# Collecting pyobjc-framework-AdSupport==8.5.1
#   Downloading pyobjc_framework_AdSupport-8.5.1-py2.py3-none-any.whl (3.0 kB)
# Collecting pyobjc-framework-DiscRecordingUI==8.5.1
#   Downloading pyobjc_framework_DiscRecordingUI-8.5.1-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-MetalKit==8.5.1
#   Downloading pyobjc_framework_MetalKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (6.5 kB)
# Collecting pyobjc-framework-PreferencePanes==8.5.1
#   Downloading pyobjc_framework_PreferencePanes-8.5.1-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-CalendarStore==8.5.1
#   Downloading pyobjc_framework_CalendarStore-8.5.1-py2.py3-none-any.whl (4.6 kB)
# Collecting pyobjc-framework-MetalPerformanceShaders==8.5.1
#   Downloading pyobjc_framework_MetalPerformanceShaders-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (19 kB)
# Collecting pyobjc-framework-SecurityFoundation==8.5.1
#   Downloading pyobjc_framework_SecurityFoundation-8.5.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-Photos==8.5.1
#   Downloading pyobjc_framework_Photos-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (9.3 kB)
# Collecting pyobjc-framework-AppTrackingTransparency==8.5.1
#   Downloading pyobjc_framework_AppTrackingTransparency-8.5.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-CoreMIDI==8.5.1
#   Downloading pyobjc_framework_CoreMIDI-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-NetworkExtension==8.5.1
#   Downloading pyobjc_framework_NetworkExtension-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (10 kB)
# Collecting pyobjc-framework-BusinessChat==8.5.1
#   Downloading pyobjc_framework_BusinessChat-8.5.1-py2.py3-none-any.whl (3.0 kB)
# Collecting pyobjc-framework-ModelIO==8.5.1
#   Downloading pyobjc_framework_ModelIO-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (13 kB)
# Collecting pyobjc-framework-FinderSync==8.5.1
#   Downloading pyobjc_framework_FinderSync-8.5.1-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-Accessibility==8.5.1
#   Downloading pyobjc_framework_Accessibility-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (7.1 kB)
# Collecting pyobjc-framework-StoreKit==8.5.1
#   Downloading pyobjc_framework_StoreKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (8.5 kB)
# Collecting pyobjc-framework-ContactsUI==8.5.1
#   Downloading pyobjc_framework_ContactsUI-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (5.7 kB)
# Collecting pyobjc-framework-AddressBook==8.5.1
#   Downloading pyobjc_framework_AddressBook-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (10 kB)
# Collecting pyobjc-framework-OSAKit==8.5.1
#   Downloading pyobjc_framework_OSAKit-8.5.1-py2.py3-none-any.whl (3.6 kB)
# Collecting pyobjc-framework-CoreML==8.5.1
#   Downloading pyobjc_framework_CoreML-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (8.2 kB)
# Collecting pyobjc-framework-Metal==8.5.1
#   Downloading pyobjc_framework_Metal-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (32 kB)
# Collecting pyobjc-framework-AVFoundation==8.5.1
#   Downloading pyobjc_framework_AVFoundation-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 1.4 MB/s eta 0:00:00
# Collecting pyobjc-framework-AppleScriptKit==8.5.1
#   Downloading pyobjc_framework_AppleScriptKit-8.5.1-py2.py3-none-any.whl (3.9 kB)
# Collecting pyobjc-framework-DVDPlayback==8.5.1
#   Downloading pyobjc_framework_DVDPlayback-8.5.1-py2.py3-none-any.whl (7.8 kB)
# Collecting pyobjc-framework-MetalPerformanceShadersGraph==8.5.1
#   Downloading pyobjc_framework_MetalPerformanceShadersGraph-8.5.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pyobjc-framework-NetFS==8.5.1
#   Downloading pyobjc_framework_NetFS-8.5.1-py2.py3-none-any.whl (3.7 kB)
# Collecting pyobjc-framework-GameCenter==8.5.1
#   Downloading pyobjc_framework_GameCenter-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-IntentsUI==8.5.1
#   Downloading pyobjc_framework_IntentsUI-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (9.9 kB)
# Collecting pyobjc-framework-IOSurface==8.5.1
#   Downloading pyobjc_framework_IOSurface-8.5.1-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-LatentSemanticMapping==8.5.1
#   Downloading pyobjc_framework_LatentSemanticMapping-8.5.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pyobjc-framework-libdispatch==8.5.1
#   Downloading pyobjc_framework_libdispatch-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (20 kB)
# Collecting pyobjc-framework-Collaboration==8.5.1
#   Downloading pyobjc_framework_Collaboration-8.5.1-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-IMServicePlugIn==8.5.1
#   Downloading pyobjc_framework_IMServicePlugIn-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (9.5 kB)
# Collecting pyobjc-framework-ExternalAccessory==8.5.1
#   Downloading pyobjc_framework_ExternalAccessory-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (6.5 kB)
# Collecting pyobjc-framework-EventKit==8.5.1
#   Downloading pyobjc_framework_EventKit-8.5.1-py2.py3-none-any.whl (5.9 kB)
# Collecting pyobjc-framework-CoreMedia==8.5.1
#   Downloading pyobjc_framework_CoreMedia-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (23 kB)
# Collecting pyobjc-framework-ScreenSaver==8.5.1
#   Downloading pyobjc_framework_ScreenSaver-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (6.3 kB)
# Collecting pyobjc-framework-VideoToolbox==8.5.1
#   Downloading pyobjc_framework_VideoToolbox-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (9.6 kB)
# Collecting pyobjc-framework-SecurityInterface==8.5.1
#   Downloading pyobjc_framework_SecurityInterface-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (7.5 kB)
# Collecting pyobjc-framework-LocalAuthenticationEmbeddedUI==8.5.1
#   Downloading pyobjc_framework_LocalAuthenticationEmbeddedUI-8.5.1-py2.py3-none-any.whl (3.2 kB)
# Collecting pyobjc-framework-NotificationCenter==8.5.1
#   Downloading pyobjc_framework_NotificationCenter-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (7.2 kB)
# Collecting pyobjc-framework-Cocoa==8.5.1
#   Downloading pyobjc_framework_Cocoa-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.4/388.4 kB 9.5 MB/s eta 0:00:000:00:01
# Collecting pyobjc-framework-Quartz==8.5.1
#   Downloading pyobjc_framework_Quartz-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 5.3 MB/s eta 0:00:00m eta 0:00:01
# Collecting pyobjc-framework-AVKit==8.5.1
#   Downloading pyobjc_framework_AVKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (8.0 kB)
# Collecting pyobjc-framework-MultipeerConnectivity==8.5.1
#   Downloading pyobjc_framework_MultipeerConnectivity-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (8.8 kB)
# Collecting pyobjc-framework-GameKit==8.5.1
#   Downloading pyobjc_framework_GameKit-8.5.1-cp36-abi3-macosx_10_9_x86_64.whl (15 kB)
# Collecting pyobjc-framework-LaunchServices==8.5.1
#   Downloading pyobjc_framework_LaunchServices-8.5.1-py2.py3-none-any.whl (3.4 kB)
# Collecting pyobjc-framework-ApplicationServices==8.5.1
#   Downloading pyobjc_framework_ApplicationServices-8.5.1-cp39-cp39-macosx_10_9_universal2.whl (25 kB)
# Building wheels for collected packages: pyscreeze, pymsgbox
#   Building wheel for pyscreeze (pyproject.toml) ... done
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.28-py3-none-any.whl size=13009 sha256=94708609dc020dd11d06ef053e1f09a69793e7bff1e4f074a32bdae7164f2363
#   Stored in directory: /Users/inseop/Library/Caches/pip/wheels/b2/cb/35/3998fb8c95724397e2967b697522ba660bbdf62b12d1da2d9a
#   Building wheel for pymsgbox (pyproject.toml) ... done
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7406 sha256=e89b9fea00bba6a86a7fa26ba5ac012172897117857efa53dc0792365abad66f
#   Stored in directory: /Users/inseop/Library/Caches/pip/wheels/ec/83/a6/df8264d6d5c838598e8f94b73854c7abb718bf1987c18605dd
# Successfully built pyscreeze pymsgbox
# Installing collected packages: PyTweening, pyscreeze, pyrect, pyperclip, pymsgbox, rubicon-objc, pyobjc-core, pygetwindow, pyobjc-framework-libdispatch, pyobjc-framework-Cocoa, mouseinfo, pyobjc-framework-WebKit, pyobjc-framework-Virtualization, pyobjc-framework-VideoSubscriberAccount, pyobjc-framework-UserNotifications, pyobjc-framework-UniformTypeIdentifiers, pyobjc-framework-SystemExtensions, pyobjc-framework-SystemConfiguration, pyobjc-framework-StoreKit, pyobjc-framework-Speech, pyobjc-framework-SoundAnalysis, pyobjc-framework-Social, pyobjc-framework-ShazamKit, pyobjc-framework-ServiceManagement, pyobjc-framework-Security, pyobjc-framework-ScriptingBridge, pyobjc-framework-ScreenTime, pyobjc-framework-ScreenSaver, pyobjc-framework-SafariServices, pyobjc-framework-ReplayKit, pyobjc-framework-Quartz, pyobjc-framework-PushKit, pyobjc-framework-PreferencePanes, pyobjc-framework-PhotosUI, pyobjc-framework-Photos, pyobjc-framework-PencilKit, pyobjc-framework-PassKit, pyobjc-framework-OSAKit, pyobjc-framework-OpenDirectory, pyobjc-framework-NotificationCenter, pyobjc-framework-NetworkExtension, pyobjc-framework-Network, pyobjc-framework-NetFS, pyobjc-framework-NaturalLanguage, pyobjc-framework-MultipeerConnectivity, pyobjc-framework-MLCompute, pyobjc-framework-MetricKit, pyobjc-framework-Metal, pyobjc-framework-MediaToolbox, pyobjc-framework-MediaAccessibility, pyobjc-framework-MailKit, pyobjc-framework-LatentSemanticMapping, pyobjc-framework-KernelManagement, pyobjc-framework-iTunesLibrary, pyobjc-framework-IOSurface, pyobjc-framework-Intents, pyobjc-framework-InstallerPlugins, pyobjc-framework-InputMethodKit, pyobjc-framework-IMServicePlugIn, pyobjc-framework-ImageCaptureCore, pyobjc-framework-GameController, pyobjc-framework-GameCenter, pyobjc-framework-FSEvents, pyobjc-framework-FinderSync, pyobjc-framework-FileProvider, pyobjc-framework-ExternalAccessory, pyobjc-framework-ExecutionPolicy, pyobjc-framework-ExceptionHandling, pyobjc-framework-EventKit, pyobjc-framework-DVDPlayback, pyobjc-framework-DiskArbitration, pyobjc-framework-DiscRecording, pyobjc-framework-DeviceCheck, pyobjc-framework-DataDetection, pyobjc-framework-CryptoTokenKit, pyobjc-framework-CoreWLAN, pyobjc-framework-CoreSpotlight, pyobjc-framework-CoreMotion, pyobjc-framework-CoreML, pyobjc-framework-CoreMIDI, pyobjc-framework-CoreMediaIO, pyobjc-framework-CoreMedia, pyobjc-framework-CoreLocation, pyobjc-framework-CoreHaptics, pyobjc-framework-CoreData, pyobjc-framework-CoreBluetooth, pyobjc-framework-CoreAudio, pyobjc-framework-Contacts, pyobjc-framework-ColorSync, pyobjc-framework-Collaboration, pyobjc-framework-ClassKit, pyobjc-framework-CFNetwork, pyobjc-framework-CallKit, pyobjc-framework-CalendarStore, pyobjc-framework-BusinessChat, pyobjc-framework-Automator, pyobjc-framework-AutomaticAssessmentConfiguration, pyobjc-framework-AuthenticationServices, pyobjc-framework-AudioVideoBridging, pyobjc-framework-AppTrackingTransparency, pyobjc-framework-AppleScriptObjC, pyobjc-framework-AppleScriptKit, pyobjc-framework-AdSupport, pyobjc-framework-AdServices, pyobjc-framework-AddressBook, pyobjc-framework-Accounts, pyobjc-framework-Vision, pyobjc-framework-VideoToolbox, pyobjc-framework-UserNotificationsUI, pyobjc-framework-SyncServices, pyobjc-framework-SpriteKit, pyobjc-framework-SecurityInterface, pyobjc-framework-SecurityFoundation, pyobjc-framework-ScreenCaptureKit, pyobjc-framework-SceneKit, pyobjc-framework-QuickLookThumbnailing, pyobjc-framework-OSLog, pyobjc-framework-ModelIO, pyobjc-framework-MetalPerformanceShaders, pyobjc-framework-MetalKit, pyobjc-framework-MediaLibrary, pyobjc-framework-MapKit, pyobjc-framework-LocalAuthentication, pyobjc-framework-LinkPresentation, pyobjc-framework-IntentsUI, pyobjc-framework-InstantMessage, pyobjc-framework-GameKit, pyobjc-framework-FileProviderUI, pyobjc-framework-DiscRecordingUI, pyobjc-framework-CoreText, pyobjc-framework-CoreServices, pyobjc-framework-CoreAudioKit, pyobjc-framework-ContactsUI, pyobjc-framewor ...
#   DEPRECATION: PyTweening is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for PyTweening ... done
#   DEPRECATION: pyrect is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for pyrect ... done
#   DEPRECATION: pyperclip is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for pyperclip ... done
#   DEPRECATION: pygetwindow is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for pygetwindow ... done
#   DEPRECATION: mouseinfo is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for mouseinfo ... done
#   DEPRECATION: pyautogui is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for pyautogui ... done
# Successfully installed PyTweening-1.0.4 mouseinfo-0.1.3 pyautogui-0.9.53 pygetwindow-0.0.9 pymsgbox-1.0.9 pyobjc-8.5.1 pyobjc-core-8.5.1 pyobjc-framework-AVFoundation-8.5.1 pyobjc-framework-AVKit-8.5.1 pyobjc-framework-Accessibility-8.5.1 pyobjc-framework-Accounts-8.5.1 pyobjc-framework-AdServices-8.5.1 pyobjc-framework-AdSupport-8.5.1 pyobjc-framework-AddressBook-8.5.1 pyobjc-framework-AppTrackingTransparency-8.5.1 pyobjc-framework-AppleScriptKit-8.5.1 pyobjc-framework-AppleScriptObjC-8.5.1 pyobjc-framework-ApplicationServices-8.5.1 pyobjc-framework-AudioVideoBridging-8.5.1 pyobjc-framework-AuthenticationServices-8.5.1 pyobjc-framework-AutomaticAssessmentConfiguration-8.5.1 pyobjc-framework-Automator-8.5.1 pyobjc-framework-BusinessChat-8.5.1 pyobjc-framework-CFNetwork-8.5.1 pyobjc-framework-CalendarStore-8.5.1 pyobjc-framework-CallKit-8.5.1 pyobjc-framework-ClassKit-8.5.1 pyobjc-framework-CloudKit-8.5.1 pyobjc-framework-Cocoa-8.5.1 pyobjc-framework-Collaboration-8.5.1 pyobjc-framework-ColorSync-8.5.1 pyobjc-framework-Contacts-8.5.1 pyobjc-framework-ContactsUI-8.5.1 pyobjc-framework-CoreAudio-8.5.1 pyobjc-framework-CoreAudioKit-8.5.1 pyobjc-framework-CoreBluetooth-8.5.1 pyobjc-framework-CoreData-8.5.1 pyobjc-framework-CoreHaptics-8.5.1 pyobjc-framework-CoreLocation-8.5.1 pyobjc-framework-CoreMIDI-8.5.1 pyobjc-framework-CoreML-8.5.1 pyobjc-framework-CoreMedia-8.5.1 pyobjc-framework-CoreMediaIO-8.5.1 pyobjc-framework-CoreMotion-8.5.1 pyobjc-framework-CoreServices-8.5.1 pyobjc-framework-CoreSpotlight-8.5.1 pyobjc-framework-CoreText-8.5.1 pyobjc-framework-CoreWLAN-8.5.1 pyobjc-framework-CryptoTokenKit-8.5.1 pyobjc-framework-DVDPlayback-8.5.1 pyobjc-framework-DataDetection-8.5.1 pyobjc-framework-DeviceCheck-8.5.1 pyobjc-framework-DictionaryServices-8.5.1 pyobjc-framework-DiscRecording-8.5.1 pyobjc-framework-DiscRecordingUI-8.5.1 pyobjc-framework-DiskArbitration-8.5.1 pyobjc-framework-EventKit-8.5.1 pyobjc-framework-ExceptionHandling-8.5.1 pyobjc-framework-ExecutionPolicy-8.5.1 pyobjc-framework-ExternalAccessory-8.5.1 pyobjc-framework-FSEvents-8.5.1 pyobjc-framework-FileProvider-8.5.1 pyobjc-framework-FileProviderUI-8.5.1 pyobjc-framework-FinderSync-8.5.1 pyobjc-framework-GameCenter-8.5.1 pyobjc-framework-GameController-8.5.1 pyobjc-framework-GameKit-8.5.1 pyobjc-framework-GameplayKit-8.5.1 pyobjc-framework-IMServicePlugIn-8.5.1 pyobjc-framework-IOSurface-8.5.1 pyobjc-framework-ImageCaptureCore-8.5.1 pyobjc-framework-InputMethodKit-8.5.1 pyobjc-framework-InstallerPlugins-8.5.1 pyobjc-framework-InstantMessage-8.5.1 pyobjc-framework-Intents-8.5.1 pyobjc-framework-IntentsUI-8.5.1 pyobjc-framework-KernelManagement-8.5.1 pyobjc-framework-LatentSemanticMapping-8.5.1 pyobjc-framework-LaunchServices-8.5.1 pyobjc-framework-LinkPresentation-8.5.1 pyobjc-framework-LocalAuthentication-8.5.1 pyobjc-framework-LocalAuthenticationEmbeddedUI-8.5.1 pyobjc-framework-MLCompute-8.5.1 pyobjc-framework-MailKit-8.5.1 pyobjc-framework-MapKit-8.5.1 pyobjc-framework-MediaAccessibility-8.5.1 pyobjc-framework-MediaLibrary-8.5.1 pyobjc-framework-MediaPlayer-8.5.1 pyobjc-framework-MediaToolbox-8.5.1 pyobjc-framework-Metal-8.5.1 pyobjc-framework-MetalKit-8.5.1 pyobjc-framework-MetalPerformanceShaders-8.5.1 pyobjc-framework-MetalPerformanceShadersGraph-8.5.1 pyobjc-framework-MetricKit-8.5.1 pyobjc-framework-ModelIO-8.5.1 pyobjc-framework-MultipeerConnectivity-8.5.1 pyobjc-framework-NaturalLanguage-8.5.1 pyobjc-framework-NetFS-8.5.1 pyobjc-framework-Network-8.5.1 pyobjc-framework-NetworkExtension-8.5.1 pyobjc-framework-NotificationCenter-8.5.1 pyobjc-framework-OSAKit-8.5.1 pyobjc-framework-OSLog-8.5.1 pyobjc-framework-OpenDirectory-8.5.1 pyobjc-framework-PassKit-8.5.1 pyobjc-framework-PencilKit-8.5.1 pyobjc-framework-Photos-8.5.1 pyobjc-framework-PhotosUI-8.5.1 pyobjc-framework-PreferencePanes-8.5.1 pyobjc-framework-PushKit-8.5.1 pyobjc-framework-Quartz-8.5.1 pyobjc-framework-QuickLookThumbnailing-8.5.1 pyobjc-framework-ReplayKit-8.5.1 pyobjc-framework-SafariService ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyautogui

# %%
pip install keyboard
# Out:
# Collecting keyboard
#   Downloading keyboard-0.13.5-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: pyobjc in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Accounts==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreData==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MailKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Vision==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Security==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Contacts==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-OSLog==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MapKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-core==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Quartz==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-EventKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Intents==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Social==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-WebKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AdServices==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Automator==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Metal==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreText==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreML==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NetFS==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameController==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Speech==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Photos==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Network==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AVKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CallKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PushKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PassKit==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==8.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc->keyboard) (8.5.1)
# Installing collected packages: keyboard
# Successfully installed keyboard-0.13.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# import keyboard
# keyboard.press_and_release('page down')

# %%
# browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
browser.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight);")
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# Input In [53], in <cell line: 2>()
#       1 # browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
# ----> 2 browser.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight);")
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:492, in WebDriver.execute_script(self, script, *args)
#     489 converted_args = list(args)
#     490 command = Command.W3C_EXECUTE_SCRIPT
# --> 492 return self.execute(command, {
#     493     'script': script,
#     494     'args': converted_args})['value']
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response['value'] = self._unwrap_value(
#     431         response.get('value', None))
#     432     return response
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# JavascriptException: Message: javascript error: Cannot read properties of undefined (reading 'scrollTo')
#   (Session info: chrome=107.0.5304.62)
# Stacktrace:
# 0   chromedriver                        0x000000010e8a1598 chromedriver + 4404632
# 1   chromedriver                        0x000000010e828fa3 chromedriver + 3911587
# 2   chromedriver                        0x000000010e4d5e6a chromedriver + 425578
# 3   chromedriver                        0x000000010e4d9037 chromedriver + 438327
# 4   chromedriver                        0x000000010e4d8ed7 chromedriver + 437975
# 5   chromedriver                        0x000000010e4d9b00 chromedriver + 441088
# 6   chromedriver                        0x000000010e543c1f chromedriver + 875551
# 7   chromedriver                        0x000000010e52bda2 chromedriver + 777634
# 8   chromedriver                        0x000000010e542f79 chromedriver + 872313
# 9   chromedriver                        0x000000010e52bbd3 chromedriver + 777171
# 10  chromedriver                        0x000000010e500ced chromedriver + 601325
# 11  chromedriver                        0x000000010e501e51 chromedriver + 605777
# 12  chromedriver                        0x000000010e8710ce chromedriver + 4206798
# 13  chromedriver                        0x000000010e875797 chromedriver + 4224919
# 14  chromedriver                        0x000000010e87ca4f chromedriver + 4254287
# 15  chromedriver                        0x000000010e8764da chromedriver + 4228314
# 16  chromedriver                        0x000000010e84f23f chromedriver + 4067903
# 17  chromedriver                        0x000000010e8936a8 chromedriver + 4347560
# 18  chromedriver                        0x000000010e893816 chromedriver + 4347926
# 19  chromedriver                        0x000000010e8a88fe chromedriver + 4434174
# 20  libsystem_pthread.dylib             0x00007ff813af34e1 _pthread_start + 125
# 21  libsystem_pthread.dylib             0x00007ff813aeef6b thread_start + 15

# %%
browser.find_element(By.CLASS_NAME, 'fysCi').click()

modal = browser.find_element(By.CLASS_NAME, 'fysCi')

import time
for i in range(1):
    browser.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight);", modal)
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [67], in <cell line: 10>()
#       7 count = 0
#       8 while True:
# ---> 10     browser.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight);", modal)
#      11     time.sleep(2)
#      13 containers = browser.find_elements(By.CLASS_NAME, 'RHo1pe')
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:492, in WebDriver.execute_script(self, script, *args)
#     489 converted_args = list(args)
#     490 command = Command.W3C_EXECUTE_SCRIPT
# --> 492 return self.execute(command, {
#     493     'script': script,
#     494     'args': converted_args})['value']
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response['value'] = self._unwrap_value(
#     431         response.get('value', None))
#     432     return response
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=107.0.5304.62)
# Stacktrace:
# 0   chromedriver                        0x000000010e8a1598 chromedriver + 4404632
# 1   chromedriver                        0x000000010e828fa3 chromedriver + 3911587
# 2   chromedriver                        0x000000010e4d5e6a chromedriver + 425578
# 3   chromedriver                        0x000000010e4d9037 chromedriver + 438327
# 4   chromedriver                        0x000000010e4d8ed7 chromedriver + 437975
# 5   chromedriver                        0x000000010e4d9b00 chromedriver + 441088
# 6   chromedriver                        0x000000010e543c1f chromedriver + 875551
# 7   chromedriver                        0x000000010e52bda2 chromedriver + 777634
# 8   chromedriver                        0x000000010e542f79 chromedriver + 872313
# 9   chromedriver                        0x000000010e52bbd3 chromedriver + 777171
# 10  chromedriver                        0x000000010e500ced chromedriver + 601325
# 11  chromedriver                        0x000000010e501e51 chromedriver + 605777
# 12  chromedriver                        0x000000010e8710ce chromedriver + 4206798
# 13  chromedriver                        0x000000010e875797 chromedriver + 4224919
# 14  chromedriver                        0x000000010e87ca4f chromedriver + 4254287
# 15  chromedriver                        0x000000010e8764da chromedriver + 4228314
# 16  chromedriver                        0x000000010e84f23f chromedriver + 4067903
# 17  chromedriver                        0x000000010e8936a8 chromedriver + 4347560
# 18  chromedriver                        0x000000010e893816 chromedriver + 4347926
# 19  chromedriver                        0x000000010e8a88fe chromedriver + 4434174
# 20  libsystem_pthread.dylib             0x00007ff813af34e1 _pthread_start + 125
# 21  libsystem_pthread.dylib             0x00007ff813aeef6b thread_start + 15

# %%
# 데이터를 수집하는 코드

import pandas as pd

containers = browser.find_elements(By.CLASS_NAME, 'RHo1pe')

data_list = []

for container in containers:
    
    user_name = container.find_element(By.CLASS_NAME, 'X5PpBb').text
#     print(user_name)
    
    rating = container.find_element(By.CLASS_NAME, 'iXRFPc').get_attribute('aria-label')[10]
#     print(rating)
   
    date = container.find_element(By.CLASS_NAME, 'bp9Aid').text
#     print(date)
    
    content = container.find_element(By.CLASS_NAME, 'h3YV2d').text
#     print(content)
    
    data = {
        "user_name": user_name,
        "rating": rating,
        "date": date,
        "content": content        
    }
    
    data_list.append(data)

df = pd.DataFrame(data_list)
df.to_csv('./playstore_comment.csv', encoding = 'utf-8-sig') # csv 파일로 저장

# %%
df = pd.read_csv('./playstore_comment.csv', encoding = 'utf-8-sig')
df = df.drop(['Unnamed: 0'], axis = 1)
# print(df.sort_values(by='date'))
# print(df.sort_values(by=['date'], ascending=True))
df.sort_values(by=['date'], inplace=True, ascending=True)
df
# Out:
#          user_name  rating           date  \
# 110     Google 사용자       2  2018년 10월 11일
# 87      Google 사용자       2  2018년 10월 11일
# 24      Google 사용자       2  2018년 10월 20일
# 100     Google 사용자       4   2018년 10월 2일
# 73      Google 사용자       5  2018년 10월 30일
# ..             ...     ...            ...
# 123            오금철       1   2022년 9월 26일
# 124  Guinness John       1   2022년 9월 30일
# 127       oh danee       4    2022년 9월 4일
# 131            이서현       1    2022년 9월 4일
# 122            박대원       4    2022년 9월 6일
#
#                                                content
# 110  왜 자기혼자 앱실행이 되는거죠? 몇번 그랬는데 잘못눌렸나 했거니 하고 넘겼는데.. ...
# 87   쿠팡 어플 좋았어요 그런데 요즘들어 어플을 키지도 않았는데 저절로 창이뜨더군요 필요...
# 24   쿠팡은 다좋은데 휴대폰이 혼자 좀비같이 팝업이 갑자기 뜨니까 곤란한상황이 몇번 발생...
# 100  검색이 빠르고 다양한 물건을 특가에 구입할 수 있어서 정말 좋습니다. 다만 배송상품...
# 73   많은 쇼핑어플중에 당연 으뜸이 아닌가싶다. 일단 무언가 상품을 찾기가 매우 편하고 ...
# ..                                                 ...
# 123  검색기능에서 단어 제외 기능이나 추가나 해주십쇼. 무센서 LED를 검색해도 센서달린...
# 124  상품 상세 설명을 보는데 스크롤을 해도 다시 원 위치로 가거나 아래로 스크롤 하는데...
# 127  배송할때 상자랑 프레쉬백 선택을 좀더 확실하게 해주시면 안될까요? 저도 선택을 하지...
# 131  배송 느려서 문의 넣는데 답은 빨리 보내드린다는데 거의 2주 넘게 배송 정지 되있고...
# 122  갤럭시폴드 유저인데 단말회전에 따라서 앱이 회전이 안되네요. 특이한건 분할화면에서는...
#
# [160 rows x 4 columns]

# %%
containers = browser.find_elements(By.CLASS_NAME, 'RHo1pe')

for container in containers:
    user_name = container.find_element(By.CLASS_NAME, 'X5PpBb').text
#     print(user_name)
    
    rating = container.find_element(By.CLASS_NAME, 'iXRFPc').get_attribute('aria-label')
    print(rating)
# Out:
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 3개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 2개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 4개를 받았습니다.
# 별표 5개 만점에 1개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
# 별표 5개 만점에 5개를 받았습니다.
